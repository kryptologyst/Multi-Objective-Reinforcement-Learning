# %% [markdown]
# # Multi-Objective Reinforcement Learning Demo
#
# This notebook demonstrates the multi-objective RL system with different environments and agents.

# %%
import sys
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# Add src to path
sys.path.append(str(Path.cwd() / "src"))

from envs.multi_objective_envs import make_multi_objective_env
from agents.multi_objective_agents import create_multi_objective_agent
from src.training import MultiObjectiveTrainer, TrainingLogger, Visualizer
